# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset - netflix1.csv")
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df['date_added'] = pd.to_datetime(df['date_added'], format = '%m/%d/%Y')

# %%
df['date_added'] = pd.to_datetime(df['date_added'], format = '%d-%m-%Y')

# %%
df['date_added'] = df['date_added'].dt.strftime('%d-%m-%Y')
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.type.value_counts()
# Out:
# Movie      6126
# TV Show    2664
# Name: type, dtype: int64

# %%
sns.countplot(x= 'type', data = df)
plt.title("Count VS Type of Shows")
# Out:
# Text(0.5, 1.0, 'Count VS Type of Shows')

# %% [markdown]
# On Netflix there are more no. of movies as compared to TV shows.

# %%
df['country'].value_counts().head(10)
# Out:
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Name: country, dtype: int64

# %%
plt.figure(figsize = (12,6))
sns.countplot(y = 'country', order = df['country'].value_counts().index[0:10], data = df)
plt.title('Country wise content on Netflix')
# Out:
# Text(0.5, 1.0, 'Country wise content on Netflix')

# %%
movie_contries = df[df['type'] == 'Movie']
tv_show_contries = df[df['type'] == 'TV Show']
plt.figure(figsize = (12,6))
sns.countplot(y = 'country', order = df['country'].value_counts().index[0:20], data = movie_contries)
plt.title('Top 10 contries producing movies on Netflix')
# Out:
# Text(0.5, 1.0, 'Top 10 contries producing movies on Netflix')

# %%
df.rating.value_counts()
# Out:
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: rating, dtype: int64

# %%
plt.figure(figsize = (9, 6))
sns.countplot(x= 'rating', order = df['rating'].value_counts().index[0:10], data = df)
plt.title('Rating of shows on Netflix VS Count')
# Out:
# Text(0.5, 1.0, 'Rating of shows on Netflix VS Count')

# %%
df.release_year.value_counts()[:20]
# Out:
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
# 2021     592
# 2015     555
# 2014     352
# 2013     286
# 2012     236
# 2010     192
# 2011     185
# 2009     152
# 2008     135
# 2006      96
# 2007      88
# 2005      80
# 2004      64
# 2003      59
# 2002      51
# Name: release_year, dtype: int64

# %%
plt.figure(figsize = (9, 6))
sns.countplot(x= 'release_year', order = df['release_year'].value_counts().index[0:20], data = df)
plt.title('Content Release in years on Netflix VS Count')
# Out:
# Text(0.5, 1.0, 'Content Release in years on Netflix VS Count')

# %%
plt.figure(figsize = (12, 8))
sns.countplot(y= 'listed_in', order = df['listed_in'].value_counts().index[0:20], data = df)
plt.title('Top 20 Genre on Netflix')
# Out:
# Text(0.5, 1.0, 'Top 20 Genre on Netflix')

# %% [markdown]
# # Summary

# %% [markdown]
# 1) Netflix has larger selection of movies compared to TV shows.

# %% [markdown]
# 2) The United States leads in producing both movies and TV shows on Netflix, with India ranking second in movie production,

# %% [markdown]
# 3) Netflix primarily targets mature audience with most of its content tailored for adults.

# %% [markdown]
# 4) 2018 saw a substancial increase in the amount of content released on Netflix compared to other years.

# %% [markdown]
# 5) International movies and dramas are the top favourite genres among Netflix viewers.
